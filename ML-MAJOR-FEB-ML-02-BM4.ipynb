# %% [markdown]
# ML-MAJOR-FEB-ML-02-BM4<br>
# Sentiment Analysis for Amazon reviews

# %%
#Importing general libraries

import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %% [markdown]
# # Data Gather: Web Scraping

# %%
#Importing csv file

products = pd.read_csv('/content/drive/MyDrive/Machine Learning/Major Project/dataset/amazon_baby.csv')

# %%
#Dataframe head

products.head()
# Out:
#                                                 name  ... rating
# 0                           Planetwise Flannel Wipes  ...      3
# 1                              Planetwise Wipe Pouch  ...      5
# 2                Annas Dream Full Quilt with 2 Shams  ...      5
# 3  Stop Pacifier Sucking without tears with Thumb...  ...      5
# 4  Stop Pacifier Sucking without tears with Thumb...  ...      5
#
# [5 rows x 3 columns]

# %%
#Dataframe tail

products.tail()
# Out:
#                                                      name  ... rating
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...  ...      5
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...  ...      5
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)  ...      5
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...  ...      5
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...  ...      5
#
# [5 rows x 3 columns]

# %%
#Review count

products['review'].value_counts()
# Out:
# good                                                                                                                                                                                                                                                                                                                                                                   5
# very nice                                                                                                                                                                                                                                                                                                                                                              5
# Very good                                                                                                                                                                                                                                                                                                                                                              5
# Excellent!                                                                                                                                                                                                                                                                                                                                                             4
# Works great                                                                                                                                                                                                                                                                                                                                                            3
#                                                                                                                                                                                                                                                                                                                                                                       ..
# Loved these pillows during my pregnancy! They helped me get comfortable which was very gardvti do lol!                                                                                                                                                                                                                                                                 1
# Received this over a week a go and this has become a huge life saver when I\'m out and about with my 6-1/2 week old.  The vibration is very strong which my daughter seems to enjoy from her falling a sleep to the vibration and the white noise.  I would recommend !Disclosure: I was given a sample of this product to review. However, my opinions are my own.    1
# Feels pretty sturdy once it\'s installed, but very difficult to install.  Instructions are really confusing, and I ended up getting more info from the picture on the box.  Kind of wish it had an auto-close feature, since it\'s at the top of our stairs, but I couldn\'t find one that would fit the weird angle, AND be permanently mounted, AND auto-close.      1
# These nail clippers come with a light so it makes clipping my newborn\'s nails so easy. I usually use them while I am feeding him or while he is sleeping so he\'s not moving around.                                                                                                                                                                                  1
# Haven\'t used it yet (as my child is unborn) but it is very soft and pretty. I can see how comfortable this could be for a newborn. Great quality!                                                                                                                                                                                                                     1
# Name: review, Length: 182642, dtype: int64

# %%
#Rating count

products['rating'].value_counts()
# Out:
# 5    107054
# 4     33205
# 3     16779
# 1     15183
# 2     11310
# Name: rating, dtype: int64

# %%
products.shape
# Out:
# (183531, 3)

# %% [markdown]
# # Preprocessing

# %%
#Total raw data
len(products)
# Out:
# 183531

# %%
#Non null values
len(products) - len(products.dropna())
# Out:
# 1147

# %%
#Removing null values

products = products.dropna()

# %%
#Classifying clomuns and checking for review column

for i in range(0,len(products)-1):
    if type(products.iloc[i]['review']) != str:
        products.iloc[i]['review'] = str(products.iloc[i]['review'])

# %%
#Splitting positive and negative reviews

def sentiment(n):
    return 'Positive' if n >= 4 else 'Negative'
products = products[products['rating'] != 3] # removing median review value
products['sentiment'] = products['rating'].apply(sentiment)
products.head()
# Out:
#                                                 name  ... sentiment
# 1                              Planetwise Wipe Pouch  ...  Positive
# 2                Annas Dream Full Quilt with 2 Shams  ...  Positive
# 3  Stop Pacifier Sucking without tears with Thumb...  ...  Positive
# 4  Stop Pacifier Sucking without tears with Thumb...  ...  Positive
# 5  Stop Pacifier Sucking without tears with Thumb...  ...  Positive
#
# [5 rows x 4 columns]

# %%
#Sentiment count

products['sentiment'].value_counts()
# Out:
# Positive    139318
# Negative     26361
# Name: sentiment, dtype: int64

# %%
#Adding feature 

def combined_features(row):
    return row['name'] + ' '+ row['review']
products['all_features'] = products.apply(combined_features, axis=1)
products.head()
# Out:
#                                                 name  ...                                       all_features
# 1                              Planetwise Wipe Pouch  ...  Planetwise Wipe Pouch it came early and was no...
# 2                Annas Dream Full Quilt with 2 Shams  ...  Annas Dream Full Quilt with 2 Shams Very soft ...
# 3  Stop Pacifier Sucking without tears with Thumb...  ...  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...  ...  Stop Pacifier Sucking without tears with Thumb...
# 5  Stop Pacifier Sucking without tears with Thumb...  ...  Stop Pacifier Sucking without tears with Thumb...
#
# [5 rows x 5 columns]

# %%
#Splitting

x = products.iloc[:,4] # contains all features
y = products.iloc[:,3] # contains positive or negative

# %% [markdown]
# # Vectorization: CountVectorizer

# %%
# train test splitting

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0,stratify=y)

# %%
#Shapes of x & y

print(x_train.shape)
print(x_test.shape)
# Out:
# (115975,)
# (49704,)

# %%
#Unique values of y_train

np.unique(y_train,return_counts=True)
# Out:
# (array(['Negative', 'Positive'], dtype=object), array([18453, 97522]))

# %%
#Unique values of y_train

np.unique(y_test,return_counts=True)
# Out:
# (array(['Negative', 'Positive'], dtype=object), array([ 7908, 41796]))

# %%
#Vectorization & Importing Pipeline, CountVectorizer, LogisticRegression

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

review_model = Pipeline([('tfidf',CountVectorizer()),('model',LogisticRegression(max_iter=2000))]) # Pipelining ( combining CountVectorizer & LogisticRegression )

# %% [markdown]
# # Logistic Regression

# %%
#Fitting the Model

review_model.fit(x_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=2000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
#Generating prediction model

y_pred = review_model.predict(x_test)

# %%
#Prediction

y_pred
# Out:
# array(['Positive', 'Positive', 'Positive', ..., 'Positive', 'Negative',
#        'Positive'], dtype=object)

# %%
#Test

y_test
# Out:
# 130708    Positive
# 135614    Positive
# 87955     Positive
# 163763    Positive
# 82752     Positive
#             ...
# 145268    Positive
# 138441    Positive
# 42890     Positive
# 182049    Positive
# 100627    Positive
# Name: sentiment, Length: 49704, dtype: object

# %% [markdown]
# # Accuracy Tests

# %%
#Accuracy Score

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)*100
# Out:
# 93.06695638178014

# %%
#Classification Report

from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.73      0.81      0.77      7114
#     Positive       0.97      0.95      0.96     42590
#
#     accuracy                           0.93     49704
#    macro avg       0.85      0.88      0.86     49704
# weighted avg       0.93      0.93      0.93     49704

# %%
#Confusion Matrix

from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred,y_test)
# Out:
# array([[ 5788,  1326],
#        [ 2120, 40470]])

# %% [markdown]
# # Random Test

# %%
import random # random
ran = int(random.randint(1,1000))
ranstr = x_test.iloc[ran]
ranstr
# Out:
# 'Evenflo Aura Select Travel System, Alhambra Excelente producto, trae la silla de carro con la base incluida (car seat) y es f&aacute;cil de instalar en el carro y en el coche para pasear al recien nacido.La compra y la entrega fueron r&aacute;pidas, excelente servicio.'

# %%
#Random Test

review_model.predict([ranstr])
# Out:
# array(['Positive'], dtype=object)

# %% [markdown]
# # Positive & Negative Splitting

# %%
#Positive Frame

pos_frame = products[products['sentiment']=='Positive']

# %%
pos_frame.head()
# Out:
#                                                 name  ...                                       all_features
# 1                              Planetwise Wipe Pouch  ...  Planetwise Wipe Pouch it came early and was no...
# 2                Annas Dream Full Quilt with 2 Shams  ...  Annas Dream Full Quilt with 2 Shams Very soft ...
# 3  Stop Pacifier Sucking without tears with Thumb...  ...  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...  ...  Stop Pacifier Sucking without tears with Thumb...
# 5  Stop Pacifier Sucking without tears with Thumb...  ...  Stop Pacifier Sucking without tears with Thumb...
#
# [5 rows x 5 columns]

# %%
#Negative Frame

neg_frame = products[products['sentiment']=='Negative']

# %%
neg_frame.head()
# Out:
#                                                  name  ...                                       all_features
# 21   Nature\'s Lullabies Second Year Sticker Calendar  ...  Nature\'s Lullabies Second Year Sticker Calend...
# 41         SoftPlay Giggle Jiggle Funbook, Happy Bear  ...  SoftPlay Giggle Jiggle Funbook, Happy Bear Thi...
# 50                          SoftPlay Cloth Book, Love  ...  SoftPlay Cloth Book, Love This book is boring....
# 70  Hunnt&reg; Falling Flowers and Birds Kids Nurs...  ...  Hunnt&reg; Falling Flowers and Birds Kids Nurs...
# 71  Wall Decor Removable Decal Sticker - Colorful ...  ...  Wall Decor Removable Decal Sticker - Colorful ...
#
# [5 rows x 5 columns]

# %% [markdown]
# # Saving & Retrieving the model: ( Pickle )

# %%
import pickle # importing pickle

#save the model to disk
filename = 'Amazon_reviews.sav'
pickle.dump(review_model, open(filename, 'wb'))

# %%
#for heroku - joblib
import joblib
joblib.dump(review_model,'Amazon_reviews')
# Out:
# ['Amazon_reviews']

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(x_test, y_test)*100
print(result)
# Out:
# 93.06695638178014

# %% [markdown]
# # Web App using Streamlit

# %%
#Installing requirements

# !pip install streamlit --quiet
# !pip install pyngrok==4.1.1 --quiet
from pyngrok import ngrok
# Out:
#      |████████████████████████████████| 8.2MB 5.6MB/s
#      |████████████████████████████████| 4.2MB 45.0MB/s
#      |████████████████████████████████| 81kB 8.4MB/s
#      |████████████████████████████████| 163kB 29.8MB/s
#      |████████████████████████████████| 112kB 45.4MB/s
#      |████████████████████████████████| 122kB 36.7MB/s
#      |████████████████████████████████| 71kB 7.3MB/s
#   Building wheel for blinker (setup.py) ... done
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.3 which is incompatible.
#   Building wheel for pyngrok (setup.py) ... done

# %%
# %%writefile app.py
import streamlit as st
import sklearn
import pickle
import pandas as pd
products = pd.read_csv('/content/drive/MyDrive/Machine Learning/Major Project/dataset/small_csv_data.csv')
filename = 'Amazon_reviews.sav'
model = pickle.load(open(filename, 'rb'))
st.title('Sentiment Analysis of Amazon Reviews')
ip = st.text_input('Enter your message')
op = model.predict([ip])
if st.button('Predict'):
  st.title(op[0])
st.table(products['Example Reviews'])
# Out:
# Writing app.py

# %%
# !nohup streamlit run app.py &
url=ngrok.connect(port='8501')
url
# Out:
# nohup: appending output to 'nohup.out'
# 'http://2555211a13bc.ngrok.io'

# %%
pip install pipreqs
# Out:
# Collecting pipreqs
#   Downloading https://files.pythonhosted.org/packages/9b/83/b1560948400a07ec094a15c2f64587b70e1a5ab5f7b375ba902fcab5b6c3/pipreqs-0.4.10-py2.py3-none-any.whl
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs) (0.6.2)
# Collecting yarg
#   Downloading https://files.pythonhosted.org/packages/8b/90/89a2ff242ccab6a24fbab18dbbabc67c51a6f0ed01f9a0f41689dc177419/yarg-0.1.9-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yarg->pipreqs) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2020.12.5)
# Installing collected packages: yarg, pipreqs
# Successfully installed pipreqs-0.4.10 yarg-0.1.9

# %%
# !pipreqs
# Out:
# INFO: Successfully saved requirements file in /content/requirements.txt
